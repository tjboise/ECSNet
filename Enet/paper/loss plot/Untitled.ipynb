# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('FCN.csv')
data
# Out:
#      Unnamed: 0   FCN loss  Deepcrack        Enet  Deeplabv3     LRASPP  \
# 0             0  17.141926  24.208153  150.126196  26.745484  28.555585
# 1             1   7.585976  14.515274   87.583135  11.527631  13.704156
# 2             2   6.071061  14.045928   59.698549   8.448317  10.412581
# 3             3   5.248031  13.288220   41.906875   6.657324   8.567406
# 4             4   4.552829  13.637205   31.209817   5.769686   7.418842
# ..          ...        ...        ...         ...        ...        ...
# 295         295   1.596511   1.109071    5.178975   1.615007   2.545659
# 296         296   1.592070   1.096135    5.204303   1.619478   2.540379
# 297         297   1.592478   1.092635    5.157521   1.619883   2.523985
# 298         298   1.593668   1.089507    5.136897   1.640385   2.545712
# 299         299   1.598307   1.117810    5.144926   1.642025   2.538018
#
#           Unet     ECSNet
# 0    43.967447  77.592493
# 1    24.285380  52.337609
# ...

# %%
data[['FCN loss','Deepcrack','Enet','Deeplabv3','LRASPP','Unet','ECSNet']].plot()
plt.yscale('log')
